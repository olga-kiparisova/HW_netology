# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# - p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# - s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуацию, когда пользователь будет вводить несуществующий документ.
# - l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# - as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень
# - d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# - m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# - a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

# p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
def people(doc_num):
    found_doc = False
    for doc in documents:
        if doc['number'] == doc_num:           
            found_doc = True
            print(f'ФИО: {doc["name"]}')
            break
    if found_doc == False:
        print('Запрошен несуществующий документ.')

#people('10005')
#people('10006')
#-----------------------------------------                 
# s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
#Правильно обработайте ситуацию, когда пользователь будет вводить несуществующий документ.
def shelf(doc_num):
    shelf_found = False
    for shelf_dir in directories.items():
        for doc_number in shelf_dir[1]:
            if doc_number == doc_num:
                shelf_found = True
                print(f'Документ находится на полке {shelf_dir[0]}')
                break
    if shelf_found == False:
        print(f'Документа {doc_num} нет на полках. Проверьте корректность ввода.')
#shelf('10005')
#shelf('10006')
#-----------------------------------------
# l– list – команда, которая выведет список всех документов в формате **passport "2207 876234" "Василий Гупкин"**;   
def list_():
    for doc in documents:
        printmd(f'**{doc["type"]} "{doc["number"]}" "{doc["name"]}"**')
#list_()

#----------------------------------------- 
# as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень
def add_shelf(shelf_num):
    if shelf_num in directories.keys():
        print('Такая полка уже есть')
    else:
        directories.update({shelf_num : []})
        print(f'Полка с номером {shelf_num} добавлена.')
#add_shelf('4')
#add_shelf('4')

#-----------------------------------------
#d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок.
#Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
def del_doc(doc_num):
    doc_deleted = False
    for doc in documents:
        if doc['number'] == doc_num:
            documents.remove(doc)
            doc_deleted = True
            print(f'Документ {doc_num} удалён.')
            break
    if doc_deleted == False:
        print(f'Документа {doc_num} нет в базе. Проверьте корректность ввода.')
        
    for docs in directories.values():
        if doc_num in docs:
            docs.remove(doc_num)

#del_doc('10005')
#del_doc('10006')
#-----------------------------------------
#m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую.
#Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ
#на несуществующую полку;
def move(doc_num, target_shelf):
    doc_exist = False
    for doc in documents:
        if doc['number'] == doc_num:
            doc_exist = True
            break
    if doc_exist == False:
        print(f'Документа {doc_num} нет в базе. Проверьте корректность ввода.')
    else:
        if target_shelf in directories.keys():
            doc_found = False
            for docs in directories.values():
                if doc_num in docs:
                    docs.remove(doc_num)
                    doc_found = True
            if doc_found == True:
                directories[target_shelf].append(doc_num)
                print(f'Документ {doc_num} успешно перемещён на полку {target_shelf}')
            else:
                print(f'Документа {doc_num} нет ни на одной из полок.') 
        else:
            print(f'Полки {target_shelf} нет в базе. Проверьте корректность ввода.')   
    
#move('10006', '2')
#print(directories)
#-----------------------------------------
#a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, 
#тип, имя владельца и номер полки, на котором он будет храниться.
def add(doc_num, doc_type, doc_owner, target_shelf):
    doc_exist = False
    for doc in documents:
        if doc['number'] == doc_num:
            doc_exist = True
            break
    if doc_exist == True:
        print(f'Документ {doc_num} уже есть в базе. Проверьте корректность ввода.')
        return
    if target_shelf not in directories.keys():
        print(f'Полки {target_shelf} нет в базе. Проверьте корректность ввода.')
        return
    new_doc = {'type': doc_type, 'number': doc_num, 'name': doc_owner}
    documents.append(new_doc)
    directories[target_shelf].append(doc_num)

#add('112','dsd','hnthhg','4')
#print(directories)
#print(documents)

# Рабочее место секретаря :)
def start_program():
    while True:
        command = input('\n \
    Выберете одну из команд: p, s, l, as, d, m, a \n \
    Для выхода введите q \n \
    Для вызова справки введите h \n \
    Введите команду: ')
        if command == 'p':
            people(input('\nВведите номер документа: '))
        elif command == 's':
            shelf(input('\nВведите номер документа: '))
        elif command == 'l':
            list_()
        elif command == 'as':
            add_shelf(input('\nДобавить новую полку. Введите номер: '))
        elif command == 'd':
            del_doc(input('\nВведите номер документа: '))
        elif command == 'm':
            move(input('\nВведите номер документа: '),
                          input('Введите номер полки, на которую переносите документ: '))
        elif command == 'a':
            add(input('\nВведите тип документа: '),
                input('Введите номер документа: '),
                input('Введите имя: '),
                input('Введите номер полки: '))
        elif command == 'q':
            break
        elif command == 'h':
            print('\n \
            p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит\n \
            s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится\n \
            l – list – команда, которая выведет список всех документов\n \
            as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень\n \
            d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок\n \
            m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую\n \
            a – add – команда, которая добавит новый документ в каталог и в перечень полок\n')
        else:
            print('Вы ввели неверную команду.')

start_program()
# Out:
#      Выберете одну из команд: p, s, l, as, d, m, a
#      Для выхода введите q
#      Для вызова справки введите h
#      Введите команду: q
